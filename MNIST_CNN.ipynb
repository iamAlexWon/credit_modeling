# %% [markdown]
# ## CNN을 활용한 MNIST 분류

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
# 초기값 설정

epochs=50
batch_size=128
n_hidden = 128
validation_split=0.2
dropout=0.3

img_rows, img_cols=28, 28 
input_shape=(img_rows, img_cols, 1)
n_classes=10

# %%
# load MNIST dataset

mnist=keras.datasets.mnist
(x_train, y_train), (x_test, y_test)=mnist.load_data()

# reshape
x_train=x_train.reshape((60000, 28, 28, 1))
x_test=x_test.reshape((10000, 28, 28, 1))

# normalize

x_train=x_train/255.0
x_test=x_test/255.0

x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

# %%
# convert class vectors to binary class metrices

y_train=tf.keras.utils.to_categorical(y_train, n_classes)
y_test=tf.keras.utils.to_categorical(y_test, n_classes)

# %%
# build a model (LeNet-5)
model=tf.keras.models.Sequential()
    # Conv => relu => pooling
model.add(keras.layers.Convolution2D(6, (5,5), activation='relu', input_shape=input_shape))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
    # Conv => relu => Pooling
model.add(keras.layers.Convolution2D(16, (5,5), activation='relu'))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
    #Flatten => relu
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(120, activation='relu'))
    #softmax classifier
model.add(keras.layers.Dense(n_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 24, 24, 6)         156
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 6)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 16)          2416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               30840
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1210
# =================================================================
# Total params: 34,622
# Trainable params: 34,622
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compiling the model
model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

# training the model
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=validation_split)

# evalution the model
test_loss, test_acc=model.evaluate(x_test, y_test)
print('Test accuracy', test_acc)
# Out:
# Epoch 1/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.3478 - accuracy: 0.8952 - val_loss: 0.2718 - val_accuracy: 0.9169
# Epoch 2/50
# 375/375 [==============================] - 4s 12ms/step - loss: 0.2548 - accuracy: 0.9210 - val_loss: 0.2203 - val_accuracy: 0.9317
# Epoch 3/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.2072 - accuracy: 0.9372 - val_loss: 0.1768 - val_accuracy: 0.9476
# Epoch 4/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.1788 - accuracy: 0.9464 - val_loss: 0.1656 - val_accuracy: 0.9487
# Epoch 5/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.1580 - accuracy: 0.9523 - val_loss: 0.1459 - val_accuracy: 0.9559
# Epoch 6/50
# 375/375 [==============================] - 5s 12ms/step - loss: 0.1428 - accuracy: 0.9558 - val_loss: 0.1328 - val_accuracy: 0.9584
# Epoch 7/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.1303 - accuracy: 0.9605 - val_loss: 0.1196 - val_accuracy: 0.9652
# Epoch 8/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.1204 - accuracy: 0.9631 - val_loss: 0.1166 - val_accuracy: 0.9657
# Epoch 9/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.1128 - accuracy: 0.9651 - val_loss: 0.1061 - val_accuracy: 0.9689
# Epoch 10/50
# 375/375 [==============================] - 5s 13ms/step - loss: 0.1066 - accuracy: 0.9676 - val_loss: 0.1070 - val_accuracy: 0.9683
# Epoch 11/50
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1009 - accuracy: 0.9689 - val_loss: 0.0997 - val_accuracy: 0.9708
# Epoch 12/50
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0961 - accuracy: 0.9710 - val_loss: 0.0980 - val_accuracy: 0.9698
# Epoch 13/50
# 375/375 [==============================] - 5s 14ms/step - loss: 0.0914 - accuracy: 0.9721 - val_loss: 0.1000 - val_accuracy: 0.9698
# Epoch 14/50
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0878 - accuracy: 0.9728 - val_loss: 0.0945 - val_accuracy: 0.9709
# Epoch 15/50
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0845 - accuracy: 0.9741 - val_loss: 0.0884 - val_accuracy: 0.9733
# Epoch 16/50
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0811 - accuracy: 0.9750 - val_loss: 0.0869 - val_accuracy: 0.9747
# Epoch 17/50
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0775 - accuracy: 0.9764 - val_loss: 0.0852 - val_accuracy: 0.9744
# Epoch 18/50
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0758 - accuracy: 0.9766 - val_loss: 0.0869 - val_accuracy: 0.9736
# Epoch 19/50
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0732 - accuracy: 0.9773 - val_loss: 0.0827 - val_accuracy: 0.9747
# Epoch 20/50
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0708 - accuracy: 0.9785 - val_loss: 0.0848 - val_accuracy: 0.9753
# Epoch 21/50
# 375/375 [==============================] - 6s 17ms/step - loss: 0.0686 - accuracy: 0.9789 - val_loss: 0.0945 - val_accuracy: 0.9711
# Epoch 22/50
# 375/375 [==============================] - 6s 17ms/step - loss: 0.0671 - accuracy: 0.9796 - val_loss: 0.0811 - val_accuracy: 0.9749
# Epoch 23/50
# 375/375 [==============================] - 6s 15ms/step - loss: 0.0650 - accuracy: 0.9802 - val_loss: 0.0761 - val_accuracy: 0.9762
# Epoch 24/50
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0640 - accuracy: 0.9803 - val_loss: 0.0783 - val_accuracy: 0.9777
# Epoch 25/50
# 375/375 [==============================] - 6s 16ms/step - loss: 0.0621 - accuracy: 0.9805 - val_loss: 0.0743 - val_accuracy: 0.9768
# Epoch 26/50
# 375/375 [==============================] - 6s 17ms/step - loss: 0.0603 - accuracy: 0.9813 - val_loss: 0.0744 - val_accuracy: 0.9781
# Epoch 27/50
# 375/375 [==============================] - 6s 17ms/step - loss: 0.0588 - accuracy: 0.9814 - val_loss: 0.0716 - val_accuracy: 0.9782
# Epoch 28/50
# 375/375 [==============================] - 6s 17ms/step - loss: 0.0573 - accuracy: 0.9823 - val_loss: 0.0700 - val_accuracy: 0.9793
# Epoch 29/50
# 375/375 [==============================] - 6s 17ms/step - loss: 0.0556 - accuracy: 0.9833 - val_loss: 0.0699 - val_accuracy: 0.9790
# Epoch 30/50
# 375/375 [==============================] - 7s 18ms/step - loss: 0.0548 - accuracy: 0.9831 - val_loss: 0.0689 - val_accuracy: 0.9789
# Epoch 31/50
# 375/375 [==============================] - 7s 18ms/step - loss: 0.0533 - accuracy: 0.9838 - val_loss: 0.0786 - val_accuracy: 0.9756
# Epoch 32/50
# 375/375 [==============================] - 7s 18ms/step - loss: 0.0518 - accuracy: 0.9838 - val_loss: 0.0693 - val_accuracy: 0.9783
# Epoch 33/50
# 375/375 [==============================] - 7s 18ms/step - loss: 0.0508 - accuracy: 0.9843 - val_loss: 0.0696 - val_accuracy: 0.9783
# Epoch 34/50
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0495 - accuracy: 0.9851 - val_loss: 0.0679 - val_accuracy: 0.9791
# Epoch 35/50
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0488 - accuracy: 0.9843 - val_loss: 0.0699 - val_accuracy: 0.9785
# Epoch 36/50
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0480 - accuracy: 0.9850 - val_loss: 0.0692 - val_accuracy: 0.9805
# Epoch 37/50
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0464 - accuracy: 0.9856 - val_loss: 0.0684 - val_accuracy: 0.9792
# Epoch 38/50
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0453 - accuracy: 0.9859 - val_loss: 0.0637 - val_accuracy: 0.9809
# Epoch 39/50
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0443 - accuracy: 0.9861 - val_loss: 0.0638 - val_accuracy: 0.9808
# Epoch 40/50
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0444 - accuracy: 0.9860 - val_loss: 0.0614 - val_accuracy: 0.9814
# Epoch 41/50
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0424 - accuracy: 0.9870 - val_loss: 0.0655 - val_accuracy: 0.9801
# Epoch 42/50
# 375/375 [==============================] - 8s 20ms/step - loss: 0.0421 - accuracy: 0.9869 - val_loss: 0.0637 - val_accuracy: 0.9800
# Epoch 43/50
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0410 - accuracy: 0.9875 - val_loss: 0.0660 - val_accuracy: 0.9804
# Epoch 44/50
# 375/375 [==============================] - 8s 20ms/step - loss: 0.0400 - accuracy: 0.9877 - val_loss: 0.0605 - val_accuracy: 0.9822
# Epoch 45/50
# 375/375 [==============================] - 8s 21ms/step - loss: 0.0393 - accuracy: 0.9880 - val_loss: 0.0658 - val_accuracy: 0.9808
# Epoch 46/50
# 375/375 [==============================] - 8s 21ms/step - loss: 0.0389 - accuracy: 0.9879 - val_loss: 0.0599 - val_accuracy: 0.9815
# Epoch 47/50
# 375/375 [==============================] - 8s 21ms/step - loss: 0.0378 - accuracy: 0.9878 - val_loss: 0.0668 - val_accuracy: 0.9798
# Epoch 48/50
# 375/375 [==============================] - 8s 21ms/step - loss: 0.0373 - accuracy: 0.9883 - val_loss: 0.0581 - val_accuracy: 0.9827
# Epoch 49/50
# 375/375 [==============================] - 8s 22ms/step - loss: 0.0365 - accuracy: 0.9883 - val_loss: 0.0583 - val_accuracy: 0.9827
# Epoch 50/50
# 375/375 [==============================] - 8s 21ms/step - loss: 0.0356 - accuracy: 0.9894 - val_loss: 0.0587 - val_accuracy: 0.9826
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0495 - accuracy: 0.9828
# Test accuracy 0.9828000068664551

# %%
# build a model (AlexNet)
model2=tf.keras.models.Sequential()
    # Conv => relu => pooling
model2.add(keras.layers.Convolution2D(6, (5,5), activation='relu', input_shape=input_shape))
model2.add(keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
    # Conv => relu => Pooling
model2.add(keras.layers.Convolution2D(16, (5,5), activation='relu'))
model2.add(keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model2.add(keras.layers.Convolution2D(16, (5,5), activation='relu', padding='same'))
model2.add(keras.layers.Convolution2D(16, (5,5), activation='relu', padding='same'))
    #Flatten => relu
model2.add(keras.layers.Flatten())
model2.add(keras.layers.Dense(120, activation='relu'))
    #softmax classifier
model2.add(keras.layers.Dense(n_classes, activation='softmax'))

model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 24, 24, 6)         156
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 6)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 16)          2416
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 16)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 16)          6416
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 16)          6416
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 120)               30840
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1210
# =================================================================
# Total params: 47,454
# Trainable params: 47,454
# Non-trainable params: 0
# _________________________________________________________________
